# %% [markdown]
# <a href="https://colab.research.google.com/github/thiyagi9/PythonPractises/blob/main/Copy_of_Data_Story_Master.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#library imports
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('max_columns', 140)
pd.set_option('precision', 3)

# %%
# Uploading "Working hours" from the working machine. This can be replaced by having the file in GDrive itself
from google.colab import files
f1 = files.upload()

# %%
print("Mounting your Google Drive ...")
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive',force_remount=True)
 
path = "/content/drive/My Drive/Colab Notebooks"#You have to update this path

fileName1 = 'italy.csv'
fileName2='finland.csv'
fileName3='netherlands.csv'
fileName4='norway.csv'
fileName5='france.csv'
CovidData='owid-covid-data.csv'

wh='WorkingHour-RemoteWork_2.csv'
# Out:
# Mounting your Google Drive ...
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
finalfile='DataStory_Happyness_MasterAll.csv'
final_master=pd.read_csv(path+'/'+finalfile)

# %%
df1=pd.read_csv(path+'/'+fileName1)
df2=pd.read_csv(path+'/'+fileName2)
df3=pd.read_csv(path+'/'+fileName3)
df4=pd.read_csv(path+'/'+fileName4)
df5=pd.read_csv(path+'/'+fileName5)
df_covid=pd.read_csv(path+'/'+CovidData)
df1['Labels']='Italy'
df2['Labels']='Finland'
df3['Labels']='Netherlands'
df4['Labels']='Norway'
df5['Labels']='France'

wh=pd.read_csv(path+'/'+wh)
#wh = pd.read_csv('WorkingHour-RemoteWork_2.csv')
wh.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (78) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (84) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (76,84) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4,5,41,78,91) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %%
df_covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.026                  0.026
# ...

# %%
df_covid_bck=df_covid.copy()
df_covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.026                  0.026
# ...

# %%
#import datetime as dt
df_covid['date_new'] = df_covid['date'].str[:7]
#df_covid['date'] = df_covid['date'].dt.strftime('%Y-%m')
#df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
#df_covid.date.dtype
#monthly = happyness2['Date'].resample('M').mean()

# %%
df_covid1=df_covid[df_covid['location'].isin(['France','Finland','Italy','Netherlands','Norway'])]
df_covid1=df_covid1[df_covid['date'].str[:4]=='2020']
                 
df_covid2=df_covid1[['location','date_new', 'total_cases','new_cases',
              'total_deaths','new_deaths',
              'total_cases_per_million',	'new_cases_per_million'
              ,'new_cases_smoothed_per_million','total_deaths_per_million','new_deaths_per_million']]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df_covid2.head()
# Out:
#       location date_new  total_cases  new_cases  total_deaths  new_deaths  \
# 29176  Finland  2020-01          1.0        1.0           NaN         NaN
# 29177  Finland  2020-01          1.0        0.0           NaN         NaN
# 29178  Finland  2020-01          1.0        0.0           NaN         NaN
# 29179  Finland  2020-02          1.0        0.0           NaN         NaN
# 29180  Finland  2020-02          1.0        0.0           NaN         NaN
#
#        total_cases_per_million  new_cases_per_million  \
# 29176                     0.18                   0.18
# 29177                     0.18                   0.00
# 29178                     0.18                   0.00
# 29179                     0.18                   0.00
# 29180                     0.18                   0.00
#
#        new_cases_smoothed_per_million  total_deaths_per_million  \
# 29176                             NaN                       NaN
# ...

# %%
wh = pd.read_csv('WorkingHour-RemoteWork_2.csv')
wh.head()

# %%
# Uploading "Country wise - happy index file" This can be replaced by having the file in GDrive itself
f2 = files.upload()
# Out:
#      <input type="file" id="files-e72c3f41-dbf0-4e09-ae00-d6d1bf565919" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e72c3f41-dbf0-4e09-ae00-d6d1bf565919">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving italy.csv to italy.csv

# %%
#happy = pd.read_csv('italy.csv')

happy= pd.concat([df1, df2,df3,df4,df5],ignore_index=True)
#print(happy.shape)

happy.head()
# Out:
#    RecordNo           endtime   qweek i1_health i2_health i7a_health  \
# 0         0  02/04/2020 09:24  week 1         4         0          0
# 1         1  02/04/2020 09:26  week 1         2         0          0
# 2         2  02/04/2020 09:28  week 1         3         2          0
# 3         3  02/04/2020 09:29  week 1         1         4          1
# 4         4  02/04/2020 09:29  week 1         1         0          0
#
#         i3_health          i4_health i5_health_1 i5_health_2 i5_health_3  \
# 0  No, I have not  No, they have not          No          No          No
# 1  No, I have not  No, they have not          No          No          No
# 2  No, I have not  No, they have not          No          No          No
# 3  No, I have not  No, they have not          No          No          No
# 4  No, I have not  No, they have not          No          No          No
#
#   i5_health_4 i5_health_5 i5_health_99 i5a_health i6_health i7b_health  \
# ...

# %%
happy.isnull().sum().sum()
# Out:
# 3270821

# %%
happy.rename(columns={'CORE_B2_4':'Hness','WCRex1':'Gover','WCRV_4':'Fear'},inplace=True)

# %%
##print(happy.shape)
#happy.dropna(axis=0,inplace=True)
#print(happy.shape)
# Out:
# (119765, 425)
# (0, 425)

# %%
happy['endtime'] = pd.to_datetime(happy['endtime'])
happy['endtime'].dtype
# Out:
# dtype('<M8[ns]')

# %%
happy.Labels.unique()
# Out:
# array(['Italy', 'Finland', 'Netherlands', 'Norway', 'France'],
#       dtype=object)

# %%
import  datetime as dt
happy['Date'] = happy['endtime'].dt.date
happy['Date'].head()
# Out:
# 0    2020-02-04
# 1    2020-02-04
# 2    2020-02-04
# 3    2020-02-04
# 4    2020-02-04
# Name: Date, dtype: object

# %%
# Creating dataset with required feilds only
happyness = happy[['RecordNo','Date','Hness','Gover','Fear','Labels']].copy()
happyness.tail()
# Out:
#         RecordNo        Date Hness           Gover Fear  Labels
# 119760     32151  2021-11-05        Somewhat badly       France
# 119761     32152  2021-11-05         Somewhat well       France
# 119762     32153  2021-11-05            Very badly       France
# 119763     32154  2021-11-05            Don't know       France
# 119764     32155  2021-11-05         Somewhat well       France

# %%
happyness_bck = happyness.copy()
#happyness = happyness_bck.copy()

# %%
happyness['Date'] = pd.to_datetime(happyness['Date'])
happyness['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
happyness['Gover'].value_counts()
# Out:
# Somewhat well     42834
#                   23060
# Somewhat badly    21715
# Very badly        14524
# Very well         11553
# Don't know         6079
# Name: Gover, dtype: int64

# %%
# The count below contain "spaces/missing values"
happyness.groupby(happyness['Date'].dt.year).count()
# Out:
#       RecordNo   Date  Hness  Gover   Fear  Labels
# Date
# 2020     86593  86593  86593  86593  86593   86593
# 2021     33172  33172  33172  33172  33172   33172

# %% [markdown]
#  #### There are two approaches below :
#  1. To continue using the Categories in "Text" format as they are (for each variable the set of catogories is different but the SCALE is the same)
#  2. To conver "Nominal/ORdinal" into -> numerical labels to bring them on a same scale

# %%
## Approach number 1 -> continuing with the text categories
happyness1 = happyness[(happyness.Gover!=' ') & (happyness.Hness!=' ') & (happyness.Fear!=' ') ]

# %%
happyness1[happyness1['Fear'] =='']
print(happyness1.Fear.unique())
# Out:
# ['I am not very scared that I will contract the Coronavirus (COVID-19)'
#  'I am fairly scared that I will contract the Coronavirus (COVID-19)'
#  'I am very scared that I will contract the Coronavirus (COVID-19)'
#  'I am not at all scared that I will contract the Coronavirus (COVID-19)'
#  "Don't know"
#  'Not applicable - I have already contracted Coronavirus (COVID-19)'
#  'Not applicable - I have already contracted Coronavirus']

# %%
ax = happyness1['Fear'].value_counts().plot(kind='barh',
                                    figsize=(14,8),
                                    title="Number for each Owner Name")
plt.show()

# %%
plt.figure(figsize=(10,5))
happyness1['Hness'].value_counts().plot(kind="barh")
plt.show()
happyness1['Gover'].value_counts().plot(kind="barh", color="C2")
plt.show()
happyness1['Fear'].value_counts().plot(kind="barh", color="C3")

#plt.legend(['Happiness','Governance','Fear'])
plt.show()

# %%
happyness1['Fear'].unique()
# Out:
# array(['I am not very scared that I will contract the Coronavirus (COVID-19)',
#        'I am fairly scared that I will contract the Coronavirus (COVID-19)',
#        'I am very scared that I will contract the Coronavirus (COVID-19)',
#        'I am not at all scared that I will contract the Coronavirus (COVID-19)',
#        "Don't know",
#        'Not applicable - I have already contracted Coronavirus (COVID-19)',
#        'Not applicable - I have already contracted Coronavirus'],
#       dtype=object)

# %%
#We need to discuss the meaning of each answer. Ex,"Don't know" and "About the same" have same meaning?
happyness_Hness=happyness1['Hness'].replace("Don't know","0")
happyness_Hness=happyness_Hness.replace("About the same","0")
happyness_Hness=happyness_Hness.replace("Somewhat more happy now","1")
happyness_Hness=happyness_Hness.replace("Much more happy now","2")
happyness_Hness=happyness_Hness.replace("Somewhat less happy now","-1")
happyness_Hness=happyness_Hness.replace("Much less happy now","-2")
happyness_Hness.unique()
# Out:
# array(['0', '1', '-1', '2', '-2'], dtype=object)

# %%
happyness1['Gover'].unique()
# Out:
# array(['Somewhat well', 'Somewhat badly', 'Very badly', 'Very well',
#        "Don't know"], dtype=object)

# %%
#We need to discuss the meaning of each answer. Ex,"Don't know" can be neutral point?
happyness_Gover=happyness1['Gover'].replace("Don't know","0")
happyness_Gover=happyness_Gover.replace("Somewhat well","1")
happyness_Gover=happyness_Gover.replace("Very well","2")
happyness_Gover=happyness_Gover.replace("Somewhat badly","-1")
happyness_Gover=happyness_Gover.replace("Very badly","-2")
happyness_Gover.unique()
# Out:
# array(['1', '-1', '-2', '2', '0'], dtype=object)

# %%
happyness1['Fear'].unique()
# Out:
# array(['I am not very scared that I will contract the Coronavirus (COVID-19)',
#        'I am fairly scared that I will contract the Coronavirus (COVID-19)',
#        'I am very scared that I will contract the Coronavirus (COVID-19)',
#        'I am not at all scared that I will contract the Coronavirus (COVID-19)',
#        "Don't know",
#        'Not applicable - I have already contracted Coronavirus (COVID-19)',
#        'Not applicable - I have already contracted Coronavirus'],
#       dtype=object)

# %%
#We need to discuss the meaning of each answer. Ex,"Don't know" and "Not applicable" have same meaning?
happyness_Fear=happyness1['Fear'].replace("Don't know","0")
happyness_Fear=happyness_Fear.replace("Not applicable - I have already contracted Coronavirus (COVID-19)","0")
happyness_Fear=happyness_Fear.replace("Not applicable - I have already contracted Coronavirus","0")
happyness_Fear=happyness_Fear.replace("I am not very scared that I will contract the Coronavirus (COVID-19)","-1")
happyness_Fear=happyness_Fear.replace("I am not at all scared that I will contract the Coronavirus (COVID-19)","-2")
happyness_Fear=happyness_Fear.replace("I am fairly scared that I will contract the Coronavirus (COVID-19)","1")
happyness_Fear=happyness_Fear.replace("I am very scared that I will contract the Coronavirus (COVID-19)","2")
happyness_Fear.unique()
# Out:
# array(['-1', '1', '2', '-2', '0'], dtype=object)

# %%
df_Manu_Encoded=pd.concat([happyness_Hness,happyness_Gover,happyness_Fear],axis=1)
df_Manu_Encoded.rename(columns={'Hness':'Hness-encoded','Gover':'Gover-encoded','Fear':'Fear-encoded'},inplace=True)
df_Manu_Encoded
# Out:
#        Hness-encoded Gover-encoded Fear-encoded
# 7011               0             1           -1
# 7012               0             1           -1
# 7013               0            -1            1
# 7014               1            -1           -1
# 7015              -1             1            1
# ...              ...           ...          ...
# 102577             0             1            2
# 102578            -1            -2            1
# 102579             1             1            1
# 102580            -1             1            1
# 102581            -1             2           -2
#
# [31924 rows x 3 columns]

# %%
df_Manu_Encoded=df_Manu_Encoded.astype(int)
happyness1_encoded=pd.concat([happyness1,df_Manu_Encoded],axis=1)
happyness1_encoded2=happyness1_encoded[["Date","Labels","Hness-encoded","Gover-encoded","Fear-encoded"]]
happyness1_encoded2
# Out:
#              Date  Labels  Hness-encoded  Gover-encoded  Fear-encoded
# 7011   2020-05-27   Italy              0              1            -1
# 7012   2020-05-27   Italy              0              1            -1
# 7013   2020-05-27   Italy              0             -1             1
# 7014   2020-05-27   Italy              1             -1            -1
# 7015   2020-05-27   Italy             -1              1             1
# ...           ...     ...            ...            ...           ...
# 102577 2020-08-22  France              0              1             2
# 102578 2020-08-22  France             -1             -2             1
# 102579 2020-08-22  France              1              1             1
# 102580 2020-08-22  France             -1              1             1
# 102581 2020-08-22  France             -1              2            -2
#
# [31924 rows x 5 columns]

# %%
# Approach no.2 -> Converting and bringing all the categories to the same "SCALE"

from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()
for i in happyness.columns[2:]:
  happyness[i+'_new'] = ord_enc.fit_transform(happyness[[i]])
happyness.head()
# Out:
#    RecordNo       Date Hness Gover Fear Labels  Hness_new  Gover_new  \
# 0         0 2020-02-04                   Italy        0.0        0.0
# 1         1 2020-02-04                   Italy        0.0        0.0
# 2         2 2020-02-04                   Italy        0.0        0.0
# 3         3 2020-02-04                   Italy        0.0        0.0
# 4         4 2020-02-04                   Italy        0.0        0.0
#
#    Fear_new  Labels_new
# 0       0.0         2.0
# 1       0.0         2.0
# 2       0.0         2.0
# 3       0.0         2.0
# 4       0.0         2.0

# %%
happyness2 = happyness[(happyness.Gover_new!=0.0) & (happyness.Hness_new!=0.0) & (happyness.Fear_new!=0.0) ]

# %%
#happyness2[happyness2['Fear_new'] ==0.0]
# Out:
# Empty DataFrame
# Columns: [RecordNo, Date, Hness, Gover, Fear, Labels, Hness_new, Gover_new, Fear_new, Labels_new]
# Index: []

# %%
happyness2.drop(columns=['Hness','Gover','Fear'],inplace=True,axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
index = happyness1_encoded2['Fear-encoded'].value_counts().index

#Date	Labels	Hness-encoded	Gover-encoded	Fear-encoded

# %%
group = pd.DataFrame({'happiness':happyness1_encoded2['Hness-encoded'].value_counts(),'Gover':happyness1_encoded2['Gover-encoded'].value_counts(),'Fear':happyness1_encoded2['Fear-encoded'].value_counts()})
group.reset_index(level=0, inplace=True)
group
# Out:
#    index  happiness  Gover   Fear
# 0     -2       1199   3752   4026
# 1     -1       2555   6029  12772
# 2      0      21105   1977   1891
# 3      1       5546  15264  10243
# 4      2       1519   4902   2992

# %%
#plt.figure(figsize=(15,5))
group.groupby('index').sum().plot.bar(rot=0)
plt.grid()
plt.show()

# %%
# Another view of above bar in Stacked format
plt.figure(figsize=(10,5))
happyness1_encoded2['Hness-encoded'].value_counts().plot(kind="bar")
plt.plot()
happyness1_encoded2['Gover-encoded'].value_counts().plot(kind="bar", color="C2")

happyness1_encoded2['Fear-encoded'].value_counts().plot(kind="bar", color="C3")
plt.legend(['Happiness','Governance','Fear'])
plt.show()

# %%
# reset_index() gives a column for counting, after groupby uses month and category
# The same logic can be applied to other categorical columns
ctdf = (happyness1_encoded2.reset_index()
          .groupby(['Date','Hness-encoded'], as_index=False)
          .count().rename(columns={'index':'ct'}))

fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (15,5)
# key gives the group name (i.e. category), data gives the actual values
for key, data in ctdf.groupby('Hness-encoded'):
    data.plot(x='Date', y='ct', ax=ax, label=key)

# %%
import datetime as dt
happyness1_encoded2['Date'] = happyness1_encoded2['Date'].dt.strftime('%Y-%m')
happyness1_encoded2.Date.dtype
#monthly = happyness2['Date'].resample('M').mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# dtype('O')

# %%
happyness1_encoded2.Labels.unique()
# Out:
# array(['Italy', 'Finland', 'Netherlands', 'Norway', 'France'],
#       dtype=object)

# %%
ready_happy = happyness1_encoded2.groupby(by=['Date','Labels']).mean().reset_index()
ready_happy.rename(columns={'Hness-encoded':'Hness_new','Gover-encoded':'Gover_new','Fear-encoded':'Fear_new'},  inplace=True)
#['Hness_new','Gover_new','Fear_new','Labels_new','RecordNo']
#ready_happy.reset_index(level=0, inplace=True)
ready_happy
# Out:
#        Date       Labels  Hness_new  Gover_new  Fear_new
# 0   2020-01  Netherlands      0.000      1.000    -1.000
# 1   2020-01       Norway     -0.078      0.531    -0.469
# 2   2020-02  Netherlands      0.042      0.775    -0.465
# 3   2020-02       Norway      0.000      0.889    -0.250
# 4   2020-03  Netherlands     -0.095      0.571    -0.357
# 5   2020-03       Norway      0.261      0.913    -0.326
# 6   2020-05      Finland      0.090      0.733    -0.541
# 7   2020-05       France      0.236     -0.397     0.111
# 8   2020-05        Italy      0.213      0.219     0.254
# 9   2020-05       Norway      0.319      0.912    -0.315
# 10  2020-06      Finland      0.146      0.735    -0.554
# 11  2020-06       France      0.198     -0.319     0.015
# 12  2020-06        Italy      0.188      0.185     0.162
# 13  2020-06  Netherlands      0.037      0.701    -0.400
# 14  2020-06       Norway      0.143      0.853    -0.317
# ...

# %%
covid_df = df_covid2.groupby(by=['date_new','location']).sum().reset_index()
#ready_happy.rename(columns={'Hness-encoded':'Hness_new','Gover-encoded':'Gover_new','Fear-encoded':'Fear_new'},  inplace=True)
#['Hness_new','Gover_new','Fear_new','Labels_new','RecordNo']
#ready_happy.reset_index(level=0, inplace=True)
covid_df
# Out:
#    date_new     location  total_cases  new_cases  total_deaths  new_deaths  \
# 0   2020-01      Finland    3.000e+00        1.0     0.000e+00         0.0
# 1   2020-01       France    3.000e+01        5.0     0.000e+00         0.0
# 2   2020-01        Italy    2.000e+00        2.0     0.000e+00         0.0
# 3   2020-02      Finland    3.400e+01        2.0     0.000e+00         0.0
# 4   2020-02       France    4.660e+02       95.0     1.900e+01         2.0
# 5   2020-02        Italy    3.966e+03     1126.0     1.020e+02        29.0
# 6   2020-02  Netherlands    8.000e+00        6.0     0.000e+00         0.0
# 7   2020-02       Norway    2.300e+01       15.0     0.000e+00         0.0
# 8   2020-03      Finland    1.338e+04     1415.0     6.900e+01        17.0
# 9   2020-03       France    4.079e+05    52178.0     2.132e+04      3524.0
# 10  2020-03        Italy    1.210e+06   104664.0     1.166e+05     12399.0
# ...

# %%
data_covid = {'date_new': ['2020-01', '2020-01']
        ,'location': ['Norway','Netherlands']
        ,'total_cases':[None,None]
        ,'new_cases':[None,None]	
        ,'total_deaths':[None,None]
        ,'new_deaths':[None,None]	
        ,'total_cases_per_million':[None,None]
        ,'new_cases_per_million':[None,None]	
        ,'new_cases_smoothed_per_million':[None,None]	
        ,'total_deaths_per_million':[None,None]	
        ,'new_deaths_per_million':[None,None]
       
        }
imputec=pd.DataFrame(data_covid)
#impute.RecordNo.isnull().sum()



covid_netherlands=covid_df[covid_df['location']=='Netherlands']
covid_norway=covid_df[covid_df['location']=='Norway']

impcovid_neth=imputec[imputec['location']=='Netherlands']
covid_neth=pd.concat([covid_netherlands,impcovid_neth],ignore_index=True)

impcovid_norway=imputec[imputec['location']=='Norway']
covid_nor=pd.concat([covid_norway,impcovid_norway],ignore_index=True)



missingcov_col = ['total_cases',
               'new_cases',
               'total_deaths',
               'new_deaths',
               'total_cases_per_million',
               'new_cases_per_million',
               'new_cases_smoothed_per_million',
               'total_deaths_per_million',
               'new_deaths_per_million']#,'Labels_new','RecordNo'

#Netherlands
for k in missingcov_col:
  covid_neth.loc[covid_neth.loc[:,k].isnull(),k]=covid_nor.loc[:,k].mean()


#Norway

for k in missingcov_col:
  covid_nor.loc[covid_nor.loc[:,k].isnull(),k]=covid_nor.loc[:,k].mean()
# Out:
#    date_new location  total_cases  new_cases  total_deaths  new_deaths  \
# 0   2020-02   Norway    2.300e+01     15.000         0.000       0.000
# 1   2020-03   Norway    5.145e+04   4626.000       234.000      39.000
# 2   2020-04   Norway    2.003e+05   3097.000      4258.000     171.000
# 3   2020-05   Norway    2.540e+05    702.000      7048.000      26.000
# 4   2020-06   Norway    2.600e+05    439.000      7290.000      14.000
# 5   2020-07   Norway    2.798e+05    361.000      7854.000       5.000
# 6   2020-08   Norway    3.098e+05   1542.000      8063.000       9.000
# 7   2020-09   Norway    3.737e+05   3245.000      8001.000      10.000
# 8   2020-10   Norway    5.127e+05   6304.000      8601.000       8.000
# 9   2020-11   Norway    8.688e+05  15819.000      8983.000      50.000
# 10  2020-12   Norway    1.319e+06  13417.000     12179.000     104.000
# 11  2020-01   Norway    4.027e+05   4506.091      6591.909      39.636
#
# ...

# %%
#ready_happy['Label'] =['Italy'
covid_inter=covid_df[~covid_df['location'].isin(['Netherlands','Norway'])]

data = {'Date': ['2020-01', '2020-01', '2020-01'
                , '2020-02','2020-02','2020-02'
                , '2020-03','2020-03','2020-03'
                , '2020-04','2020-04','2020-04', '2020-04','2020-04'
                ,'2020-05','2020-12']
        ,'Labels': ['Italy', 'Finland', 'France'
                    ,'Italy','Finland', 'France'
                    ,'Italy','Finland','France'
                    ,'Italy','Finland', 'France','Norway','Netherlands'
                    ,'Netherlands','Netherlands']
       #,'RecordNo':[None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None]
        ,'Hness_new':[None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None]
        ,'Gover_new':[None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None]
        ,'Fear_new':[None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None]
       # ,'Labels_new':[None,None,None,None,None,None,None,None,None,None,None,None,None,None,None,None]
        }
impute=pd.DataFrame(data )
#impute.RecordNo.isnull().sum()



#ready_happy

# %%
covid_final=pd.concat([covid_inter,covid_nor,covid_neth],ignore_index=True)
covid_final
# Out:
#    date_new     location  total_cases   new_cases  total_deaths  new_deaths  \
# 0   2020-01      Finland    3.000e+00       1.000     0.000e+00       0.000
# 1   2020-01       France    3.000e+01       5.000     0.000e+00       0.000
# 2   2020-01        Italy    2.000e+00       2.000     0.000e+00       0.000
# 3   2020-02      Finland    3.400e+01       2.000     0.000e+00       0.000
# 4   2020-02       France    4.660e+02      95.000     1.900e+01       2.000
# 5   2020-02        Italy    3.966e+03    1126.000     1.020e+02      29.000
# 6   2020-03      Finland    1.338e+04    1415.000     6.900e+01      17.000
# 7   2020-03       France    4.079e+05   52178.000     2.132e+04    3524.000
# 8   2020-03        Italy    1.210e+06  104664.000     1.166e+05   12399.000
# 9   2020-04      Finland    9.947e+04    3577.000     2.863e+03     194.000
# 10  2020-04       France    3.456e+06  116583.000     4.866e+05   20823.000
# ...

# %%
readyhappy_italy=ready_happy[ready_happy['Labels']=='Italy']
readyhappy_norway=ready_happy[ready_happy['Labels']=='Norway']
readyhappy_netherlands=ready_happy[ready_happy['Labels']=='Netherlands']
readyhappy_finland=ready_happy[ready_happy['Labels']=='Finland']
readyhappy_france=ready_happy[ready_happy['Labels']=='France']

imp_italy=impute[impute['Labels']=='Italy']
int_italy=pd.concat([readyhappy_italy,imp_italy],ignore_index=True)

imp_neth=impute[impute['Labels']=='Netherlands']
int_neth=pd.concat([readyhappy_netherlands,imp_neth],ignore_index=True)

imp_fin=impute[impute['Labels']=='Finland']
int_fin=pd.concat([readyhappy_finland,imp_fin],ignore_index=True)

imp_fran=impute[impute['Labels']=='France']
int_fran=pd.concat([readyhappy_france,imp_fran],ignore_index=True)

imp_nor=impute[impute['Labels']=='Norway']
int_nor=pd.concat([readyhappy_norway,imp_nor],ignore_index=True)


#Italy Impute
missing_col = ['Hness_new','Gover_new','Fear_new']#,'Labels_new','RecordNo'

#Using mean to impute the missing values
for i in missing_col:
 int_italy.loc[int_italy.loc[:,i].isnull(),i]=int_italy.loc[:,i].mean()
int_italy

#imp_italy=impute[impute['Labels']=='Italy']
#int_italy=pd.concat([readyhappy_italy,imp_italy],ignore_index=True)

#Netherlands
for i in missing_col:
 int_neth.loc[int_neth.loc[:,i].isnull(),i]=int_neth.loc[:,i].mean()

#Finland

for i in missing_col:
 int_fin.loc[int_fin.loc[:,i].isnull(),i]=int_fin.loc[:,i].mean()

#France

for i in missing_col:
 int_fran.loc[int_fran.loc[:,i].isnull(),i]=int_fran.loc[:,i].mean()

#Norwar

for i in missing_col:
 int_nor.loc[int_nor.loc[:,i].isnull(),i]=int_nor.loc[:,i].mean()

# %%
ready_happy1=pd.concat([int_italy,int_neth,int_fin,int_fran,int_nor],ignore_index=True)
#happy= pd.concat([df1, df2,df3,df4,df5],ignore_index=True)
#ready_happy1

# %%
# Out:
#      Labels  RemoteWork  Reduction-WokingHour  Change-WokingHour  WorkingHour  \
# 0      EU27        12.4                   7.0               -7.0       94.350
# 1   Belgium        17.3                   8.0               -8.0       97.375
# 2  Bulgaria         1.2                   5.0               -5.0       95.375
# 3   Denmark        17.7                   2.0               -2.0       98.300
# 4   Estonia        12.7                   5.0               -5.0       86.025
#
#    Change-GDP
# 0        -6.2
# 1        -6.7
# 2        -3.6
# 3        -3.0
# 4        -3.2

# %%
#month = ['2020-01','2020-02','2020-03','2020-04','2020-05','2020-06','2020-07','2020-08','2020-09','2020-01','2020-01','2020-01']
wh[wh['Labels']=='Italy']
# Out:
#    Labels  RemoteWork  Reduction-WokingHour  Change-WokingHour  WorkingHour  \
# 10  Italy        12.3                  11.0              -11.0       88.075
#
#     Change-GDP
# 10        -8.4

# %%
wh.Labels.unique()
# Out:
# array(['EU27', 'Belgium', 'Bulgaria', 'Denmark', 'Estonia', 'Ireland',
#        'Greece', 'Spain', 'France', 'Croatia', 'Italy', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Hungary', 'Malta', 'Netherlands',
#        'Austria', 'Poland', 'Portugal', 'Romania', 'Slovenia', 'Slovakia',
#        'Finland', 'Sweden', 'Iceland', 'Norway', 'Switzerland', 'Turkey',
#        nan], dtype=object)

# %%
happyness2_bck=ready_happy1.copy()
wh_bck = wh.copy()

# %%
#wh.merge(happyness2, on="Labels").set_index(['Labels','Date','Hness_new','Gover_new','Fear_new'],inplace=True)
#wh[wh.Labels=='Italy']

# %%
index = [('Turkey','2020-01'), ('Turkey', '2020-02'),('Turkey', '2020-03'),('Turkey', '2020-04'),('Turkey', '2020-05'),('Turkey', '2020-06'),('Turkey', '2020-07'),('Turkey', '2020-08'),('Turkey', '2020-09'),('Turkey', '2020-10'),('Turkey', '2020-11'),('Turkey', '2020-12'),
         ('Finland', '2020-01'), ('Finland', '2020-02'),('Finland', '2020-03'),('Finland', '2020-04'),('Turkey', '2020-05'),('Finland', '2020-06'),('Finland', '2020-07'),('Finland', '2020-08'),('Finland', '2020-09'),('Finland', '2020-10'),('Finland', '2020-11'),('Finland', '2020-12'),
         ('Italy', '2020-01'), ('Italy', '2020-02'),('Italy', '2020-03'),('Italy', '2020-04'),('Italy', '2020-05'),('Italy', '2020-06'),('Italy', '2020-07'),('Italy', '2020-08'),('Italy', '2020-09'),('Italy', '2020-10'),('Italy', '2020-11'),('Italy', '2020-12'),
         ('Netherlands', '2020-01'), ('Netherlands', '2020-02'),('Netherlands', '2020-03'),('Netherlands', '2020-04'),('Netherlands', '2020-05'),('Netherlands', '2020-06'),('Netherlands', '2020-07'),('Netherlands', '2020-08'),('Netherlands', '2020-09'),('Netherlands', '2020-10'),('Netherlands', '2020-11'),('Netherlands', '2020-12'),
         ('Switzerland', '2020-01'), ('Switzerland', '2020-02'),('Switzerland', '2020-03'),('Switzerland', '2020-04'),('Switzerland', '2020-05'),('Switzerland', '2020-06'),('Switzerland', '2020-07'),('Switzerland', '2020-08'),('Switzerland', '2020-09'),('Switzerland', '2020-10'),('Switzerland', '2020-11'),('Switzerland', '2020-12')]

# %%
wh1 = wh[wh['Labels'].isin(['France','Finland','Italy','Netherlands','Norway'])]
wh1.head()
# Out:
#          Labels  RemoteWork  Reduction-WokingHour  Change-WokingHour  \
# 8        France        16.0                   8.0               -8.0
# 10        Italy        12.3                  11.0              -11.0
# 16  Netherlands        18.9                   3.0               -3.0
# 23      Finland        25.9                   2.0               -2.0
# 26       Norway         4.8                   4.0               -4.0
#
#     WorkingHour  Change-GDP
# 8        97.450        -8.4
# 10       88.075        -8.4
# 16      107.700        -4.3
# 23       98.475        -2.9
# 26      106.200        -1.3

# %%
wh1= pd.concat([wh1]*12, ignore_index=True)

# %%
wh1 = wh1.sort_values(by=['Labels'])
wh1.shape
# Out:
# (60, 6)

# %%
#wh1

# %%
wh1['Date'] = ['2020-01','2020-02','2020-03','2020-04','2020-05','2020-06','2020-07','2020-08','2020-09','2020-10','2020-11','2020-12']*5

# %%
wh1.head(60)
# Out:
#          Labels  RemoteWork  Reduction-WokingHour  Change-WokingHour  \
# 53      Finland        25.9                   2.0               -2.0
# 43      Finland        25.9                   2.0               -2.0
# 38      Finland        25.9                   2.0               -2.0
# 33      Finland        25.9                   2.0               -2.0
# 58      Finland        25.9                   2.0               -2.0
# 28      Finland        25.9                   2.0               -2.0
# 23      Finland        25.9                   2.0               -2.0
# 18      Finland        25.9                   2.0               -2.0
# 13      Finland        25.9                   2.0               -2.0
# 48      Finland        25.9                   2.0               -2.0
# 8       Finland        25.9                   2.0               -2.0
# 3       Finland        25.9                   2.0               -2.0
# 10       France        16.0                   8.0               -8.0
# ...

# %%
#col_l = ['RemoteWork','Reduction-WokingHour','Change-WokingHour','WorkingHour','Change-GDP']
#for i in col_l:
#  if wh1['Date'].isin(['2020-01','2020-04','2020-07','2020-10']):
#    wh1[i] == wh1[i]-1
#  elif wh1['Date'].isin(['2020-03','2020-06','2020-09','2020-12']):
#    wh1[i] == wh1[i]+1
#wh1.head()

# %%
index = pd.MultiIndex.from_tuples(index)

# %%
# Need to create a frame "data" contains only 'Happy,gover,fear' from happyness and RemoteWork	Reduction-WokingHour	Change-WokingHour	WorkingHour	Change-GDP from wh ' 
# With Stack() and unstack() methods we can convert index into columns

# %%
col_list = ['Hness_new','Gover_new','Fear_new']
ser1 = list()
for col in col_list:
  val = happyness2[col].to_list()
  ser1.append(val)
np.array(ser1).shape
# Out:
# (3, 7026)

# %%
ser2 = list()
for col in wh.columns:
  val = wh[col].to_list()
  ser2.append(val)
np.array(ser2).shape
# Out:
# (6, 34)

# %%
 data = pd.Series([ser1,ser2])

# %%
ready_happy1.head()
# Out:
#       Date Labels  Hness_new  Gover_new  Fear_new
# 0  2020-05  Italy      0.213      0.219     0.254
# 1  2020-06  Italy      0.188      0.185     0.162
# 2  2020-07  Italy      0.114      0.273     0.211
# 3  2020-08  Italy      0.081      0.150     0.243
# 4  2020-09  Italy      0.195      0.212     0.133

# %%
new_df = pd.merge(ready_happy1, wh1,  how='inner', left_on=['Date','Labels'], right_on = ['Date','Labels'])
new_df=new_df.sort_values(by=['Date','Labels'])
#new_df = pd.merge(A_df, B_df,  how='left', left_on=['A_c1','c2'], right_on = ['B_c1','c2'])

# %%
#new_df.reset_index(inplace=True)
#s=pd.Series(range(len(new_df)))
#s
new_df.set_index(pd.Series(range(len(new_df))),inplace=True)

# %%
finalfile='DataStory_Happyness_MasterAll.csv'
final_master=pd.read_csv(path+'/'+finalfile)
final_master.head(100)
# Out:
#     Unnamed: 0     Date       Labels  Hness_new  Hness_new+2  Gover_new  \
# 0            0  2020-01      Finland      0.101        2.101      0.660
# 1            5  2020-02      Finland      0.101        2.101      0.660
# 2           10  2020-03      Finland      0.101        2.101      0.660
# 3           15  2020-04      Finland      0.101        2.101      0.660
# 4           20  2020-05      Finland      0.090        2.090      0.733
# 5           25  2020-06      Finland      0.146        2.146      0.735
# 6           30  2020-07      Finland      0.060        2.060      0.709
# 7           35  2020-08      Finland      0.014        2.014      0.562
# 8           40  2020-09      Finland      0.119        2.119      0.773
# 9           45  2020-10      Finland      0.121        2.121      0.751
# 10          50  2020-11      Finland      0.103        2.103      0.807
# 11          55  2020-12      Finland      0.158        2.158      0.211
# ...

# %%
final_master.drop('Unnamed: 0',axis=1,inplace=True)

# %%
final_df=pd.merge(final_master,covid_final,how='inner', left_on=['Date','Labels'], right_on = ['date_new','location'])

# %%
final_df_bck=final_df.copy()

# %%
final_df.drop(['date_new','location'],axis=1,inplace=True)

# %%
final_df.head(100)

# %%
final_df.to_csv(path+'/'+'DataStory_Happiness_CovidCases.csv')
