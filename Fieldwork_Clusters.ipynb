# %% [markdown]
# <a href="https://colab.research.google.com/github/thiyagi9/PythonPractises/blob/main/Fieldwork_Clusters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive',force_remount=True)
 
path = "/content/drive/My Drive/Colab Notebooks/"#You have to update this path

fileName = 'complete_clusterStandard.csv'



df=pd.read_csv(path+'/'+fileName)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Cluster

# %%
#df.groupby(by='CUSTOMER_ID').agg(cluster)

df.groupby('cluster')['cluster'].count()
# Out:
# cluster
# 0     463
# 1    8581
# 2    4643
# 3    2939
# 4    6866
# 6    1596
# Name: cluster, dtype: int64

# %%
df.shape
# Out:
# (25088, 101)

# %%
df1=df[df['cluster']==0]
df2=df[df['cluster']==1]
df3=df[df['cluster']==2]
df4=df[df['cluster']==3]
df5=df[df['cluster']==4]
#df6=df[df['cluster']==5]
df7=df[df['cluster']==6]

# %%
df1.shape
# Out:
# (463, 101)

# %%
#df1_cluster1=df1[['CUSTOMER_ID','cat_1','cat_2','cat_3','cat_4','cat_6','cat_7','cat_9','cat_10','cat_11','cat_12','cat_13','cat_15','cat_16','TOTAL_PURCHASE']]

# %%
dh1_cluster1=df1[['CUSTOMER_ID','hour_freq_0','hour_freq_9','hour_freq_12','hour_freq_15','hour_freq_18','hour_freq_21']]
dh2_cluster2=df2[['CUSTOMER_ID','hour_freq_0','hour_freq_9','hour_freq_12','hour_freq_15','hour_freq_18','hour_freq_21']]
dh3_cluster3=df3[['CUSTOMER_ID', 'hour_freq_0','hour_freq_9','hour_freq_12','hour_freq_15','hour_freq_18','hour_freq_21']]
dh4_cluster4=df4[['CUSTOMER_ID','hour_freq_0','hour_freq_9','hour_freq_12','hour_freq_15','hour_freq_18','hour_freq_21']]
dh5_cluster5=df5[['CUSTOMER_ID','hour_freq_0','hour_freq_9','hour_freq_12','hour_freq_15','hour_freq_18','hour_freq_21']]
#dh6_cluster6=df6[['CUSTOMER_ID','hour_freq_0','hour_freq_9','hour_freq_12','hour_freq_15','hour_freq_18','hour_freq_21']]
dh7_cluster7=df7[['CUSTOMER_ID','hour_freq_0','hour_freq_9','hour_freq_12','hour_freq_15','hour_freq_18','hour_freq_21']]

# %%
df1_cluster1=df1[['CUSTOMER_ID','cat_1','cat_2','cat_3','cat_4','cat_6','cat_7','cat_9','cat_10','cat_11','cat_12','cat_13','cat_15','cat_16']]
df2_cluster2=df2[['CUSTOMER_ID','cat_1','cat_2','cat_3','cat_4','cat_6','cat_7','cat_9','cat_10','cat_11','cat_12','cat_13','cat_15','cat_16']]
df3_cluster3=df3[['CUSTOMER_ID','cat_1','cat_2','cat_3','cat_4','cat_6','cat_7','cat_9','cat_10','cat_11','cat_12','cat_13','cat_15','cat_16']]
df4_cluster4=df4[['CUSTOMER_ID','cat_1','cat_2','cat_3','cat_4','cat_6','cat_7','cat_9','cat_10','cat_11','cat_12','cat_13','cat_15','cat_16']]
df5_cluster5=df5[['CUSTOMER_ID','cat_1','cat_2','cat_3','cat_4','cat_6','cat_7','cat_9','cat_10','cat_11','cat_12','cat_13','cat_15','cat_16']]
#df6_cluster6=df6[['CUSTOMER_ID','cat_1','cat_2','cat_3','cat_4','cat_6','cat_7','cat_9','cat_10','cat_11','cat_12','cat_13','cat_15','cat_16']]
df7_cluster7=df7[['CUSTOMER_ID','cat_1','cat_2','cat_3','cat_4','cat_6','cat_7','cat_9','cat_10','cat_11','cat_12','cat_13','cat_15','cat_16']]

# %%
dh1_cluster1.head()
# Out:
#     CUSTOMER_ID  hour_freq_0  ...  hour_freq_18  hour_freq_21
# 107  AC02755843            0  ...             0             0
# 114  AC04724596            0  ...             0             0
# 156  AE00344135            0  ...             0             0
# 236  AG00422147            0  ...             0             0
# 249  AG02291879            0  ...             0             0
#
# [5 rows x 7 columns]

# %%
df1_cluster1_new = df1_cluster1.melt(id_vars = 'CUSTOMER_ID', var_name = ['cat'], value_name = 'Value')  
df2_cluster2_new = df2_cluster2.melt(id_vars = 'CUSTOMER_ID', var_name = ['cat'], value_name = 'Value')  
df3_cluster3_new = df3_cluster3.melt(id_vars = 'CUSTOMER_ID', var_name = ['cat'], value_name = 'Value')  
df4_cluster4_new = df4_cluster4.melt(id_vars = 'CUSTOMER_ID', var_name = ['cat'], value_name = 'Value')  
df5_cluster5_new = df5_cluster5.melt(id_vars = 'CUSTOMER_ID', var_name = ['cat'], value_name = 'Value')  
#df6_cluster6_new = df6_cluster6.melt(id_vars = 'CUSTOMER_ID', var_name = ['cat'], value_name = 'Value')  
df7_cluster7_new = df7_cluster7.melt(id_vars = 'CUSTOMER_ID', var_name = ['cat'], value_name = 'Value')

# %%
dh1_cluster1_new = dh1_cluster1.melt(id_vars = 'CUSTOMER_ID', var_name = ['hour'], value_name = 'Value')  
dh2_cluster2_new = dh2_cluster2.melt(id_vars = 'CUSTOMER_ID', var_name = ['hour'], value_name = 'Value')  
dh3_cluster3_new = dh3_cluster3.melt(id_vars = 'CUSTOMER_ID', var_name = ['hour'], value_name = 'Value')  
dh4_cluster4_new = dh4_cluster4.melt(id_vars = 'CUSTOMER_ID', var_name = ['hour'], value_name = 'Value')  
dh5_cluster5_new = dh5_cluster5.melt(id_vars = 'CUSTOMER_ID', var_name = ['hour'], value_name = 'Value')  
#dh6_cluster6_new = dh6_cluster6.melt(id_vars = 'CUSTOMER_ID', var_name = ['hour'], value_name = 'Value')  
dh7_cluster7_new = dh7_cluster7.melt(id_vars = 'CUSTOMER_ID', var_name = ['hour'], value_name = 'Value')

# %%
dh1_cluster1_new.head()
# Out:
#   CUSTOMER_ID         hour  Value
# 0  AA00339963  hour_freq_0      0
# 1  AA00455487  hour_freq_0      0
# 2  AA01078597  hour_freq_0      0
# 3  AA03554934  hour_freq_0      0
# 4  AB00338766  hour_freq_0      0

# %%
df_check1=df1_cluster1_new.groupby('cat').mean('Value').reset_index()
df_check2=df2_cluster2_new.groupby('cat').mean('Value').reset_index()
df_check3=df3_cluster3_new.groupby('cat').mean('Value').reset_index()
df_check4=df4_cluster4_new.groupby('cat').mean('Value').reset_index()
df_check5=df5_cluster5_new.groupby('cat').mean('Value').reset_index()
#df_check6=df6_cluster6_new.groupby('cat').mean('Value').reset_index()
df_check7=df7_cluster7_new.groupby('cat').mean('Value').reset_index()

 #metro_sales.groupby(['cust_id', 'store_id', 'month']).agg(aggregations).reset_index()

# %%
dh_check1=dh1_cluster1_new.groupby('hour').sum('Value').reset_index()
dh_check2=dh2_cluster2_new.groupby('hour').sum('Value').reset_index()
dh_check3=dh3_cluster3_new.groupby('hour').sum('Value').reset_index()
dh_check4=dh4_cluster4_new.groupby('hour').sum('Value').reset_index()
dh_check5=dh5_cluster5_new.groupby('hour').sum().reset_index()
#dh_check6=dh6_cluster6_new.groupby('hour').mean('Value').reset_index()
dh_check7=dh7_cluster7_new.groupby('hour').sum().reset_index()

 #metro_sales.groupby(['cust_id', 'store_id', 'month']).agg(aggregations).reset_index()

# %%
print(df_check1,df_check2)
# Out:
#        cat      Value
# 0    cat_1   3.460043
# 1   cat_10   3.317495
# 2   cat_11   1.138229
# 3   cat_12   0.935205
# 4   cat_13   0.563715
# 5   cat_15   0.051836
# 6   cat_16   0.576674
# 7    cat_2   0.159827
# 8    cat_3   4.365011
# 9    cat_4  10.894168
# 10   cat_6   1.444924
# 11   cat_7   3.200864
# 12   cat_9   2.533477        cat     Value
# 0    cat_1  7.652372
# 1   cat_10  4.690013
# 2   cat_11  1.075982
# 3   cat_12  0.690246
# 4   cat_13  0.391796
# 5   cat_15  0.079012
# 6   cat_16  0.838014
# 7    cat_2  0.094278
# 8    cat_3  3.578604
# 9    cat_4  0.888475
# 10   cat_6  0.253933
# 11   cat_7  2.343200
# 12   cat_9  2.143456

# %%
import numpy as np

# Add a bar in the polar coordinates
plt.subplot(111, polar=True);
plt.bar(x=0, height=10, width=np.pi/2, bottom=5);

# %%
import matplotlib.pyplot as plt
import numpy as np

# Initialize plot with polar coordinates.
plt.subplot(111, polar=True);

plt.figure(figsize=(20,10))

# plot polar axis
ax = plt.subplot(111, polar=True)

# remove grid
plt.axis('off')

# Set the coordinates limits
upperLimit = 100
lowerLimit = 30

# Compute max and min in the dataset
max = df_check['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_check.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_check.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_check.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white")

# %%
# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# little space between the bar and the label
labelPadding = 4

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_check1["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax.set_title('Categories Cluster 0')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 0')

# %%
# initialize the figure
plt.figure(figsize=(20,10))
ax1 = plt.subplot(111, polar=True)
plt.axis('off')

# Draw bars
bars1 = ax1.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# little space between the bar and the label
labelPadding = 4

# Add labels
for bar, angle, height, label in zip(bars1,angles, heights, df_check4["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax1.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax1.set_title('Categories Cluster 1')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 1')

# %%
df_check
# Out:
#                   cat  n_of_transactions
# 0               cat_1            44081.0
# 1              cat_10            41894.0
# 2              cat_11            14137.0
# 3              cat_12             8199.0
# 4              cat_13             6226.0
# 5              cat_15              199.0
# 6              cat_16             5195.0
# 7               cat_2             2315.0
# 8               cat_3            93662.0
# 9               cat_4            19682.0
# 10              cat_6             6278.0
# 11              cat_7            32187.0
# 12              cat_9            20371.0
# 13  n_of_transactions           294432.0

# %% [markdown]
# # Cluster0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
df_cl1 = df_check1.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = df_cl1['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_cl1.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_cl1.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_cl1.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_cl1["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax.set_title('Categories Cluster 0')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 0')

# %% [markdown]
# ## Hours Cluster 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
dh_cl1 = dh_check1.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = dh_cl1['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * dh_cl1.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(dh_cl1.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(dh_cl1.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, dh_cl1["hour"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax.set_title('Purchase during Hours of the Day - Cluster 0')
# Out:
# Text(0.5, 1.05, 'Purchase during Hours of the Day - Cluster 0')

# %% [markdown]
# # Cluster 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
df_cl2 = df_check2.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = df_cl2['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_cl2.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_cl2.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_cl2.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_cl2["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 

ax.set_title('Categories Cluster 1')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 1')

# %% [markdown]
# ## Hours of day cluster 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
dh_cl2 = dh_check2.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = dh_cl2['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * dh_cl2.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(dh_cl2.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(dh_cl2.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, dh_cl2["hour"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax.set_title('Purchase during Hours of the Day - Cluster 1')
# Out:
# Text(0.5, 1.05, 'Purchase during Hours of the Day - Cluster 1')

# %% [markdown]
# # Cluster 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
df_cl3 = df_check3.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = df_cl3['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_cl3.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_cl3.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_cl3.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_cl3["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 

ax.set_title('Categories Cluster 2')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 2')

# %% [markdown]
# # Hours 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
dh_cl3 = dh_check3.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = dh_cl3['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * dh_cl3.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(dh_cl3.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(dh_cl3.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, dh_cl3["hour"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax.set_title('Purchase during Hours of the Day - Cluster 2')
# Out:
# Text(0.5, 1.05, 'Purchase during Hours of the Day - Cluster 2')

# %% [markdown]
# ## Hour 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
dh_cl4 = dh_check4.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = dh_cl4['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * dh_cl4.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(dh_cl4.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(dh_cl4.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, dh_cl4["hour"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax.set_title('Purchase during Hours of the Day - Cluster 3')
# Out:
# Text(0.5, 1.05, 'Purchase during Hours of the Day - Cluster 3')

# %% [markdown]
# # Hours 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
dh_cl5 = dh_check5.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = dh_cl5['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * dh_cl5.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(dh_cl5.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(dh_cl5.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, dh_cl5["hour"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax.set_title('Purchase during Hours of the Day - Cluster 4')
# Out:
# Text(0.5, 1.05, 'Purchase during Hours of the Day - Cluster 4')

# %% [markdown]
# # Hours 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
dh_cl7 = dh_check7.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = dh_cl7['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * dh_cl7.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(dh_cl7.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(dh_cl7.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, dh_cl7["hour"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 
ax.set_title('Purchase during Hours of the Day - Cluster 6')
# Out:
# Text(0.5, 1.05, 'Purchase during Hours of the Day - Cluster 6')

# %% [markdown]
# # Cluster 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
df_cl4 = df_check4.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = df_cl4['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_cl4.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_cl4.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_cl4.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_cl4["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 

ax.set_title('Categories Cluster 3')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 3')

# %% [markdown]
# # Cluster 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
df_cl5 = df_check5.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = df_cl5['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_cl5.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_cl5.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_cl5.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_cl5["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 

ax.set_title('Categories Cluster 4')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 4')

# %% [markdown]
# # Cluster 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
df_cl6 = df_check6.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = df_cl6['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_cl6.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_cl6.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_cl6.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_cl6["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 

ax.set_title('Categories Cluster 5')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 5')

# %% [markdown]
# # Cluster 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset


# Reorder the dataframe
df_cl7 = df_check7.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(20,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 100
lowerLimit = 30
labelPadding = 4

# Compute max and min in the dataset
max = df_cl7['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_cl7.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_cl7.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_cl7.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_cl7["cat"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor") 

ax.set_title('Categories Cluster 6')
# Out:
# Text(0.5, 1.05, 'Categories Cluster 6')

# %%
df1.head()
# Out:
#    CUSTOMER_ID  cash_cnt_s  ...  pay_method_freq_4  cluster
# 2   AA00325975           1  ...                  0        3
# 9   AA00405977          31  ...                  0        3
# 17  AA01039954           0  ...                  0        3
# 19  AA01053942           0  ...                  0        3
# 24  AA01393171           0  ...                  0        3
#
# [5 rows x 101 columns]
